# %%
# Importamos librearias a utilizar # 

import numpy as np
import pandas as pd

# %%
amazon = pd.read_csv('amazon_prime_titles.csv')
amazon.head(3)
# Out:
#   show_id   type                 title      director  \
# 0      s1  Movie   The Grand Seduction  Don McKellar
# 1      s2  Movie  Take Care Good Night  Girish Joshi
# 2      s3  Movie  Secrets of Deception   Josh Webber
#
#                                                 cast        country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent         Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...  United States
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017    NaN   74 min  Action, Drama, Suspense
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# ...

# %%
# Creamos nueva columna llamada id_1 y aignamos valor de a

amazon_1 = amazon.assign(id_1 = 'a')
# amazon_1.head(3)

# %%
# Concatenar la columna id_1 con la columna show_id en una nueva columna 'id' y eliminamos la columna creada anteriormente 

amazon_1['id'] = amazon_1['id_1'] + " " + amazon_1['show_id']
amazon_1.drop(['id_1'], axis = 1, inplace = True)
# amazon_1.head()

# %%
# Reemplazar los valores nulos por el string 'G'

# amazon_1.isnull().sum()   #Contamos los valores nulos de las columnas

amazon_1['rating'].fillna('G', inplace = True)
# amazon_1.head()

# %%
# Revisamos el tipo de datos del dataframe
# amazon_1.info()

# %%
# Modificamos el tipo de dato de la columna 'date_added' por un formato AA-MM-DD

amazon_1['date_added'] = pd.to_datetime(amazon_1['date_added'])

# %%
# Dividimos el campo 'duration' por dos campos 'duration_int' y 'duration_type'

amazon_1[['duration_int','duration_type']]= amazon_1.duration.str.split(' ', expand=True)
# amazon_1.head()

# %%
# Cambiamos el tipo de dato de las columnas creadas con anterioridad

amazon_1['duration_int'] = amazon_1['duration_int'].astype('int64')
amazon_1['duration_type'] = amazon_1['duration_type'].astype('string')

# %%
amazon_2 = amazon_1.assign(plt = 'amazon')

# %%
amazon_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   show_id        9668 non-null   object
#  1   type           9668 non-null   object
#  2   title          9668 non-null   object
#  3   director       7586 non-null   object
#  4   cast           8435 non-null   object
#  5   country        672 non-null    object
#  6   date_added     155 non-null    datetime64[ns]
#  7   release_year   9668 non-null   int64
#  8   rating         9668 non-null   object
#  9   duration       9668 non-null   object
#  10  listed_in      9668 non-null   object
#  11  description    9668 non-null   object
#  12  id             9668 non-null   object
#  13  duration_int   9668 non-null   int64
#  14  duration_type  9668 non-null   string
#  15  plt            9668 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(12), string(1)
# ...

# %%
# Revisión de datos de la plataforma disney

disney = pd.read_csv('disney_plus_titles.csv')
# disney.head(3)
#disney.info()

# %%
disney_1 = disney.assign(id_1 = 'd') 
#disney.head(3)
#disney_1 = disney.assign(id_1 = 'd')

# %%
disney_1['id'] = disney_1['id_1'] + " " + disney_1['show_id']
disney_1.drop(['id_1'], axis = 1, inplace = True)
# disney_1.head()

# %%
disney_1['rating'].fillna('G', inplace = True)

# %%
disney_1['date_added'] = pd.to_datetime(disney_1['date_added'])

# %%
disney_1[['duration_int','duration_type']]= disney_1.duration.str.split(' ', expand=True)

# %%
disney_1['duration_int'] = disney_1['duration_int'].astype('int64')
disney_1['duration_type'] = disney_1['duration_type'].astype('string')

# disney_1.head(3)

# %%
disney_2 = disney_1.assign(plt = 'disney')

# %%
disney_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   show_id        1450 non-null   object
#  1   type           1450 non-null   object
#  2   title          1450 non-null   object
#  3   director       977 non-null    object
#  4   cast           1260 non-null   object
#  5   country        1231 non-null   object
#  6   date_added     1447 non-null   datetime64[ns]
#  7   release_year   1450 non-null   int64
#  8   rating         1450 non-null   object
#  9   duration       1450 non-null   object
#  10  listed_in      1450 non-null   object
#  11  description    1450 non-null   object
#  12  id             1450 non-null   object
#  13  duration_int   1450 non-null   int64
#  14  duration_type  1450 non-null   string
#  15  plt            1450 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(12), string(1)
# ...

# %%
# Revision de datos de la plataforma hulu

hulu = pd.read_csv('hulu_titles.csv')
#hulu.head(3)
hulu_1 = hulu.assign(id_1 = 'd')

# %%
hulu_1['id'] = hulu_1['id_1'] + " " + hulu_1['show_id']
hulu_1.drop(['id_1'], axis = 1, inplace = True)

# %%
hulu_1['rating'].fillna('G', inplace = True)

# %%
hulu_1['date_added'] = pd.to_datetime(hulu_1['date_added'])

# %%
hulu_1[['duration_int','duration_type']]= hulu_1.duration.str.split(' ', expand=True)

# %%
hulu_1['duration_int'].fillna(0, inplace = True)
hulu_1['duration_type'].fillna(0, inplace = True)

# %%
hulu_1['duration_int'] = hulu_1['duration_int'].astype('int64')
hulu_1['duration_type'] = hulu_1['duration_type'].astype('string')

# %%
hulu_2 = hulu_1.assign(plt = 'hulu')

# %%
hulu_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3073 entries, 0 to 3072
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   show_id        3073 non-null   object
#  1   type           3073 non-null   object
#  2   title          3073 non-null   object
#  3   director       3 non-null      object
#  4   cast           0 non-null      float64
#  5   country        1620 non-null   object
#  6   date_added     3045 non-null   datetime64[ns]
#  7   release_year   3073 non-null   int64
#  8   rating         3073 non-null   object
#  9   duration       2594 non-null   object
#  10  listed_in      3073 non-null   object
#  11  description    3069 non-null   object
#  12  id             3073 non-null   object
#  13  duration_int   3073 non-null   int64
#  14  duration_type  3073 non-null   string
#  15  plt            3073 non-null   object
# ...

# %%
# Revisión de datos de la plataforma netflix

netflix = pd.read_csv('netflix_titles.csv')
# netflix.head(3)
netflix_1 = netflix.assign(id_1 = 'd')

# %%
netflix_1['id'] = netflix_1['id_1'] + " " + netflix_1['show_id']
netflix_1.drop(['id_1'], axis = 1, inplace = True)

# %%
netflix_1['rating'].fillna('G', inplace = True)

# %%
netflix_1['date_added'] = pd.to_datetime(netflix_1['date_added'])

# %%
netflix_1[['duration_int','duration_type']]= netflix_1.duration.str.split(' ', expand=True)

# %%
netflix_1['duration_int'].fillna(0, inplace = True)
netflix_1['duration_type'].fillna(0, inplace = True)

# %%
netflix_1['duration_int'] = netflix_1['duration_int'].astype('int64')
netflix_1['duration_type'] = netflix_1['duration_type'].astype('string')

# %%
netflix_2 = netflix_1.assign(plt = 'netflix')

# %%
netflix_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   show_id        8807 non-null   object
#  1   type           8807 non-null   object
#  2   title          8807 non-null   object
#  3   director       6173 non-null   object
#  4   cast           7982 non-null   object
#  5   country        7976 non-null   object
#  6   date_added     8797 non-null   datetime64[ns]
#  7   release_year   8807 non-null   int64
#  8   rating         8807 non-null   object
#  9   duration       8804 non-null   object
#  10  listed_in      8807 non-null   object
#  11  description    8807 non-null   object
#  12  id             8807 non-null   object
#  13  duration_int   8807 non-null   int64
#  14  duration_type  8807 non-null   string
#  15  plt            8807 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(12), string(1)
# ...

# %%
df = pd.concat([amazon_2, netflix_2, hulu_2, disney_2], axis = 0)
df.sample(5)
# Out:
#      show_id     type                               title       director  \
# 899     s900    Movie                       Illegal Woman  Ramon Térmens
# 1342   s1343    Movie  Dragon Quest: The Adventure of Dai            NaN
# 882     s883    Movie                           Storm Boy     Shawn Seet
# 1569   s1570    Movie               The Postcard Killings            NaN
# 2761   s2762  TV Show                               Rugal            NaN
#
#                                                    cast  \
# 899   Daniel Faraldo, Isak Férriz, Yolanda Sey, Raqu...
# 1342                                                NaN
# 882   Jai Courtney, Geoffrey Rush, Finn Little, Trev...
# 1569                                                NaN
# 2761  Choi Jin-hyuk, Park Sung-woong, Cho Dong-hyuk,...
#
#                             country date_added  release_year    rating  \
# 899                           Spain 2021-05-11          2020     TV-MA
# ...

# %%
df.drop_duplicates()
# Out:
#      show_id   type                                           title  \
# 0         s1  Movie                             The Grand Seduction
# 1         s2  Movie                            Take Care Good Night
# 2         s3  Movie                            Secrets of Deception
# 3         s4  Movie                              Pink: Staying True
# 4         s5  Movie                                   Monster Maker
# ...      ...    ...                                             ...
# 1445   s1446  Movie                        X-Men Origins: Wolverine
# 1446   s1447  Movie  Night at the Museum: Battle of the Smithsonian
# 1447   s1448  Movie                                 Eddie the Eagle
# 1448   s1449  Movie                            Bend It Like Beckham
# 1449   s1450  Movie           Captain Sparky vs. The Flying Saucers
#
#              director                                               cast  \
# 0        Don McKellar     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent
# ...

# %%
df['plt'] = df['plt'].astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22998 entries, 0 to 1449
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   show_id        22998 non-null  object
#  1   type           22998 non-null  object
#  2   title          22998 non-null  object
#  3   director       14739 non-null  object
#  4   cast           17677 non-null  object
#  5   country        11499 non-null  object
#  6   date_added     13444 non-null  datetime64[ns]
#  7   release_year   22998 non-null  int64
#  8   rating         22998 non-null  object
#  9   duration       22516 non-null  object
#  10  listed_in      22998 non-null  object
#  11  description    22994 non-null  object
#  12  id             22998 non-null  object
#  13  duration_int   22998 non-null  int64
#  14  duration_type  22998 non-null  string
#  15  plt            22998 non-null  string
# dtypes: datetime64[ns](1), int64(2), object(11), string(2)
# ...

# %%
df['cast'] = df['cast'].astype('string')

# %%
df.isnull().sum()
# Out:
# show_id              0
# type                 0
# title                0
# director          8259
# cast              5321
# country          11499
# date_added        9554
# release_year         0
# rating               0
# duration           482
# listed_in            0
# description          4
# id                   0
# duration_int         0
# duration_type        0
# plt                  0
# dtype: int64

# %%
df['cast'].fillna('Sin dato', inplace = True)

# %%
df.to_csv('csv_final.csv')

# %% [markdown]
# 1. Película con mayor duración con filtros opcionales de AÑO, PLATAFORMA Y TIPO DE DURACIÓN. (la función debe llamarse get_max_duration(year, platform, duration_type))

# %%
def get_max_duration(year:int, plataform: str, duration_type:str ):
    
    dt_f = df[(df['release_year'] == year) & (df['plt'] == plataform)]
    
    if duration_type == 'min':
        titulo = dt_f.loc[dt_f.duration_int.idxmax()]['title']
    else:
        titulo = dt_f.loc[dt_f.duration_int.idmax()]['title']
    return titulo

# %%
a = get_max_duration(2015, 'netflix', 'min')
a
# Out:
# 'The Gospel of Luke'

# %% [markdown]
# 2. Cantidad de películas por plataforma con un puntaje mayor a XX en determinado año (la función debe llamarse get_score_count(platform, scored, year))

# %%
csv1 = pd.read_csv('./ratings/1.csv')

# %%
csv1.drop_duplicates()
# Out:
#          userId  rating   timestamp movieId
# 0             1     1.0  1425941529   as680
# 1             1     4.5  1425942435  ns2186
# 2             1     5.0  1425941523  hs2381
# 3             1     5.0  1425941546  ns3663
# 4             1     5.0  1425941556  as9500
# ...         ...     ...         ...     ...
# 1499995   15424     4.0  1370209959  as8698
# 1499996   15424     3.5  1369586045  as3663
# 1499997   15424     3.0  1372541792  as1325
# 1499998   15424     3.5  1372541811  ns4446
# 1499999   15424     3.5  1369606242  hs2569
#
# [1499986 rows x 4 columns]

# %%
csv2 = pd.read_csv('./ratings/2.csv')
csv2.drop_duplicates()
# Out:
#          userId  rating   timestamp movieId
# 0         15424     3.0  1369585147  ns3012
# 1         15424     2.5  1369586851  ns3195
# 2         15424     3.0  1369585112   ns357
# 3         15424     2.5  1372541498  as7069
# 4         15424     3.0  1369586846  as6943
# ...         ...     ...         ...     ...
# 1499995   31331     4.0   867662780  as2992
# 1499996   31331     5.0   867662780  as8070
# 1499997   31331     4.0   867663188  as7838
# 1499998   31332     4.0   974205034  ns5462
# 1499999   31332     4.0   974205170  hs2852
#
# [1499990 rows x 4 columns]

# %%
csv3 = pd.read_csv('./ratings/3.csv')
csv3.drop_duplicates()
# Out:
#          userId  rating   timestamp movieId
# 0         31332     4.0   974205261  as2251
# 1         31332     3.0   974205170  as7226
# 2         31332     3.0   974205034  as6479
# 3         31332     3.0   974205261  ns2422
# 4         31332     4.0   974205034  as4041
# ...         ...     ...         ...     ...
# 1499995   46200     4.0   994446596  as1415
# 1499996   46200     3.0   996245672   as927
# 1499997   46200     4.0   994446583  as8130
# 1499998   46200     4.0   996245646  ns5545
# 1499999   46200     4.0  1004466542  ns3187
#
# [1499977 rows x 4 columns]

# %%
csv4 = pd.read_csv('./ratings/4.csv')
csv4.drop_duplicates()
# Out:
#          userId  rating   timestamp movieId
# 0         46200     5.0  1015603683  as3203
# 1         46200     1.0  1012323069  as5959
# 2         46200     3.0   996245609  as4430
# 3         46200     4.0   996245595  as6604
# 4         46200     3.0   996245595   ds311
# ...         ...     ...         ...     ...
# 1499995   61768     3.5  1438075483  hs1021
# 1499996   61768     3.0  1438075487   hs885
# 1499997   61768     4.0  1435694368  as4321
# 1499998   61768     4.0  1438075493  hs2422
# 1499999   61768     3.5  1438075491  as6170
#
# [1499982 rows x 4 columns]

# %%
csv5 = pd.read_csv('./ratings/5.csv')
csv5.drop_duplicates()
# Out:
#          userId  rating   timestamp movieId
# 0         61768     4.0  1438075492  as5376
# 1         61768     3.0  1435693148  as7172
# 2         61768     3.0  1438075482  ns4557
# 3         61768     3.0  1438075496  ns7804
# 4         61768     3.5  1438075486  as3030
# ...         ...     ...         ...     ...
# 1499995   77403     4.0   852669256  as2081
# 1499996   77403     3.0   852669256  ns4047
# 1499997   77403     3.0   852669255   ns787
# 1499998   77403     3.0   852669333   hs541
# 1499999   77403     5.0   852669333  ns7174
#
# [1499992 rows x 4 columns]

# %%
csv6 = pd.read_csv('./ratings/6.csv')
csv6.drop_duplicates()
# Out:
#          userId  rating   timestamp movieId
# 0        249182     3.5  1460518555   ds327
# 1        249182     4.0  1461878500  ns2124
# 2        249182     3.0  1460182087  as8841
# 3        249182     4.5  1460183214  hs2318
# 4        249182     2.5  1460184332  as5743
# ...         ...     ...         ...     ...
# 1499995  265409     5.0   891417264  as4345
# 1499996  265409     5.0   891417377  ns5982
# 1499997  265409     4.0   891417191  ns4622
# 1499998  265409     5.0   891417377  as3351
# 1499999  265409     4.0   891417573  ns6806
#
# [1499978 rows x 4 columns]

# %%
csv7 = pd.read_csv('./ratings/7.csv')
csv7.drop_duplicates()
# Out:
#         userId  rating   timestamp movieId
# 0       265409     5.0   891417042   ds781
# 1       265409     5.0   891417042  as9331
# 2       265409     4.0   891417435   hs384
# 3       265409     3.0   891417191   hs398
# 4       265409     5.0   891417224  as8434
# ...        ...     ...         ...     ...
# 524284  270896     5.0  1257031564   hs447
# 524285  270896     5.0  1257032032  ns8706
# 524286  270896     4.5  1257031764  ns4476
# 524287  270896     4.5  1257033990  ns6149
# 524288  270896     2.0  1257031858  as6079
#
# [524280 rows x 4 columns]

# %%
csv8 = pd.read_csv('./ratings/8.csv')
csv8.drop_duplicates()
# Out:
#          userId  rating   timestamp movieId
# 0        108422     4.5  1350689762  as1399
# 1        108422     4.0  1350341401  as6724
# 2        108422     5.0  1350689691   ns512
# 3        108422     4.5  1350341088  ns7444
# 4        108422     4.5  1350689619  as2230
# ...         ...     ...         ...     ...
# 1499995  124380     4.5  1196786159  ns5272
# 1499996  124380     2.5  1196786030  ns5492
# 1499997  124380     3.5  1196785679   hs305
# 1499998  124380     4.5  1196787089  ns7881
# 1499999  124380     1.5  1196785847   as883
#
# [1499980 rows x 4 columns]

# %%
df_rating = pd.concat([csv1, csv2, csv3, csv4, csv5, csv6, csv7, csv8], axis = 0)
df_rating
# Out:
#          userId  rating   timestamp movieId
# 0             1     1.0  1425941529   as680
# 1             1     4.5  1425942435  ns2186
# 2             1     5.0  1425941523  hs2381
# 3             1     5.0  1425941546  ns3663
# 4             1     5.0  1425941556  as9500
# ...         ...     ...         ...     ...
# 1499995  124380     4.5  1196786159  ns5272
# 1499996  124380     2.5  1196786030  ns5492
# 1499997  124380     3.5  1196785679   hs305
# 1499998  124380     4.5  1196787089  ns7881
# 1499999  124380     1.5  1196785847   as883
#
# [11024289 rows x 4 columns]

# %%
def get_score_count(platform: str, scored: int, year: int):
    count = df_rating[df_rating['movieid'].str.contains(platform[0], case = False)]
    cant = count[(count.rating > scored) & (count.release_year == year)]

    return {'plataforma':platform, 'cantidad': len(cant)}

# %% [markdown]
# 3. Cantidad de películas por plataforma con filtro de PLATAFORMA. (La función debe llamarse get_count_platform(platform))

# %%
def get_count_platform(platform:str):
    res_1 = ((df['plt'] == platform) & (df['type'].str.contains('Movie'))).sum()
    res_2 = ((df['plt'] == platform) & (df['type'].str.contains('TV Show'))).sum()

    return ('Plataforma: ' + str(platform) + '  ' + 'Movie: '  + str(res_1)+ '  ' + 'TV Show: '  + str(res_2))

# %%
b = get_count_platform('netflix')
b
# Out:
# 'Plataforma: netflix  Movie: 6131  TV Show: 2676'

# %% [markdown]
# 4. Actor que más se repite según plataforma y año. (La función debe llamarse get_actor(platform, year))

# %%
def get_actor(platform:str, year:int):
    data_actor = df[(df['plt'] == platform) & (df['release_year'] == year)]
    for i in data_actor['cast']:
        if i != 'Sin dato':
            i = i.replace(', ', ',')
        else:
            continue
    lista = []
    for i in data_actor['cast']:
        if i != 'Sin dato':
            n=i.split(',')
            for j in range(len(n)):
                if n[j] not in lista:
                    lista.append(n[j])
                else:
                    continue
        else:
            continue
    
    lista = list(set(lista))
    m = 0
    diccionario = {}
    for i in lista:
        m = 0
        for j in data_actor['cast']:
            if i in j.split(','):
                m += 1
        diccionario[i] = m
    return print(max(diccionario, key=diccionario.get))
